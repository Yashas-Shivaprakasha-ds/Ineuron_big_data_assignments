# %% [markdown]
# # Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", sep=",")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Q3. How do you select rows from a Pandas DataFrame based on a condition

# %%
# import pandas as pd
# df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", sep=",")
df[df["Fare"] > 10]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q4. How do you rename columns in a Pandas DataFrame?

# %%
#creating new column
df["new_column"] = "input_new_column"
# renaming new_column
df.rename(columns = {'new_column':'updated_input_column'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q5. How do you drop columns in a Pandas DataFrame?

# %%
df.drop(columns=['new_column'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
df[df["Name"] == "Braund, Mr. Owen Harris"]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked        new_column
# 0      0  A/5 21171  7.25   NaN        S  input_new_column

# %% [markdown]
# # Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
df[df["Cabin"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
df.ffill(axis = 1)
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 886         887        0      2
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
#
#                                                   Name     Sex     Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0     1
# 2                               Heikkinen, Miss. Laina  female    26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0     1
# 4                             Allen, Mr. William Henry    male    35.0     0
# ..                                                 ...     ...     ...   ...
# ...

# %% [markdown]
# # Q9. How do you concatenate two Pandas DataFrames?

# %%
import pandas as pd
data_01 = {
    "name": "abc",
    "skills": ["java", "python"],
    "years_of_exp" : 2
}
df1 = pd.DataFrame(data_01)
print(df1)

data_02 = {
    "name": "xyz",
    "skills": ["javascript", "python"],
    "years_of_exp" : 2.5
}
df2 = pd.DataFrame(data_02)
print(df2)

concat_res = pd.concat([df1,df2], axis = 1)
concat_res
# Out:
#   name  skills  years_of_exp
# 0  abc    java             2
# 1  abc  python             2
#   name      skills  years_of_exp
# 0  xyz  javascript           2.5
# 1  xyz      python           2.5
#   name  skills  years_of_exp name      skills  years_of_exp
# 0  abc    java             2  xyz  javascript           2.5
# 1  abc  python             2  xyz      python           2.5

# %% [markdown]
# # Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
import pandas as pd
data_01 = {
    "name": "abc",
    "skills": ["java", "python"],
    "years_of_exp" : 2
}
df1 = pd.DataFrame(data_01)
print(df1)

data_02 = {
    "name": "xyz",
    "skills": ["javascript", "python"],
    "years_of_exp" : 4
}
print(df2)
df2 = pd.DataFrame(data_02)

updated_merge = df1.merge(df2)
print(updated_merge)

# %% [markdown]
# # Q11. How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", sep=",")
df.groupby("Fare").sum()
# Out:
#           PassengerId  Survived  Pclass    Age  SibSp  Parch
# Fare
# 0.0000           7746         1      29  246.0      0      0
# 4.0125            379         0       3   20.0      0      0
# 5.0000            873         0       1   33.0      0      0
# 6.2375            327         0       3   61.0      0      0
# 6.4375            844         0       3   34.5      0      0
# ...               ...       ...     ...    ...    ...    ...
# 227.5250         2357         3       4   98.0      1      0
# 247.5208          419         1       2   74.0      0      2
# 262.3750         1055         2       2   39.0      4      4
# 263.0000          898         2       4  130.0     10     10
# 512.3292         1677         3       3  106.0      0      1
#
# [248 rows x 6 columns]

# %% [markdown]
# # Q12. How do you pivot a Pandas DataFrame?

# %%
df.pivot_table(columns ="Name", values = "Age",aggfunc = "count")
# Out:
# Name  Abbing, Mr. Anthony  Abbott, Mr. Rossmore Edward  \
# Age                     1                            1
#
# Name  Abbott, Mrs. Stanton (Rosa Hunt)  Abelson, Mr. Samuel  \
# Age                                  1                    1
#
# Name  Abelson, Mrs. Samuel (Hannah Wizosky)  Adahl, Mr. Mauritz Nils Martin  \
# Age                                       1                               1
#
# Name  Adams, Mr. John  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  \
# Age                 1                                               1
#
# Name  Aks, Mrs. Sam (Leah Rosen)  Albimona, Mr. Nassef Cassem  ...  \
# Age                            1                            1  ...
#
# Name  Yrois, Miss. Henriette ("Mrs Harbeck")  Zabour, Miss. Hileni  \
# Age                                        1                     1
#
# Name  Zabour, Miss. Thamine  Zimmerman, Mr. Leo  \
# Age                       0                   1
#
# ...

# %% [markdown]
# # Q13. How do you change the data type of a column in a Pandas DataFrame?

# %%
df.dtypes
data_types_dict = {'new_col_01': str}
df = df.astype(data_types_dict)
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# new_column      object
# new_col_01      object
# dtype: object

# %% [markdown]
# # Q14. How do you sort a Pandas DataFrame by a specific column?

# %%
df["Name"].sort_values()
# Out:
# 845                      Abbing, Mr. Anthony
# 746              Abbott, Mr. Rossmore Edward
# 279         Abbott, Mrs. Stanton (Rosa Hunt)
# 308                      Abelson, Mr. Samuel
# 874    Abelson, Mrs. Samuel (Hannah Wizosky)
#                        ...
# 286                  de Mulder, Mr. Theodore
# 282                de Pelsmaeker, Mr. Alfons
# 361                del Carlo, Mr. Sebastiano
# 153          van Billiard, Mr. Austin Blyler
# 868              van Melkebeke, Mr. Philemon
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# # Q15. How do you create a copy of a Pandas DataFrame?

# %%
import pandas as pd
 
# Define a dictionary containing employee data 
data1 = {'skills': ['java', 'python', 'C++', 'C'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[21, 19, 20, 22],} 
   
# Define a dictionary containing employee data 
data2 = {'skills': ['java', 'python', 'C++', 'C'],
         'Address':['Bengaluru', 'Hubali', 'Mysore', 'Mandya'], 
        'Qualification':['B.E', 'B.A', 'B.com', 'B.hons']} 
 
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1)
 
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2) 

res = pd.merge(df, df1, on='skills')
 
res
# Out:
#    skills    Name  Age    Address Qualification
# 0    java     Jai   21  Bengaluru           B.E
# 1  python  Princi   19     Hubali           B.A
# 2     C++  Gaurav   20     Mysore         B.com
# 3       C    Anuj   22     Mandya        B.hons

# %% [markdown]
# # Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
df[(df["Fare"] > 100) & (df["Fare"] <200) & (df["Sex"] == "male")]
# Out:
#      PassengerId  Survived  Pclass  \
# 305          306         1       1
# 332          333         0       1
# 373          374         0       1
# 390          391         1       1
# 505          506         0       1
# 544          545         0       1
# 550          551         1       1
# 659          660         0       1
# 660          661         1       1
# 698          699         0       1
# 802          803         1       1
#
#                                            Name   Sex    Age  SibSp  Parch  \
# 305              Allison, Master. Hudson Trevor  male   0.92      1      2
# 332                   Graham, Mr. George Edward  male  38.00      0      1
# 373                         Ringhini, Mr. Sante  male  22.00      0      0
# 390                  Carter, Mr. William Ernest  male  36.00      1      2
# 505  Penasco y Castellana, Mr. Victor de Satode  male  18.00      1      0
# 544                  Douglas, Mr. Walter Donald  male  50.00      1      0
# ...

# %% [markdown]
# # Q17. How do you calculate the mean of a column in a Pandas DataFrame?

# %%
df["Fare"].mean()
# Out:
# 32.2042079685746

# %% [markdown]
# # Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
df["Fare"].std()
# Out:
# 49.693428597180905

# %% [markdown]
# # Q19. How do you calculate the correlation between two columns in a Pandas DataFrame?

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# new_col_01      0.981952  0.043764 -0.138361  0.055221 -0.026153  0.039280
#
#                  Fare  new_col_01
# PassengerId  0.012658    0.981952
# Survived     0.257307    0.043764
# Pclass      -0.549500   -0.138361
# Age          0.096067    0.055221
# SibSp        0.159651   -0.026153
# Parch        0.216225    0.039280
# Fare         1.000000    0.201546
# ...

# %% [markdown]
# # Q20. How do you select specific columns in a DataFrame using their labels?

# %%
df.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# new_column                                 input_new_column
# new_col_01                                             57.1
# Name: 3, dtype: object

# %% [markdown]
# # Q21. How do you select specific rows in a DataFrame using their indexes?

# %%
df.loc[2]["Name"]
# Out:
# 'Heikkinen, Miss. Laina'

# %% [markdown]
# # Q22. How do you sort a DataFrame by a specific column?

# %%
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# # Q23. How do you create a new column in a DataFrame based on the values of another column?

# %%
df["new_col_01"] = df["PassengerId"] + df["Fare"]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q24. How do you remove duplicates from a DataFrame?

# %%
display(df.drop_duplicates())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Q25. What is the difference between .loc and .iloc in Pandas?

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", sep=",")
# loc : It is label based, i.e, we have to specify rows and columns based on their row and column labels
# Syntax: loc[row_label, column_label]
df.loc[2, "Name"]
# Out:
# 'Heikkinen, Miss. Laina'

# %%
# iloc: It cis integer position-based, we have to specify rows and columns by their integer position values (0-based integer position)
# Syntax: iloc[row_position, column_position]
df.iloc[2, 2]
# Out:
# 3
